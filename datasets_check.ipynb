# %% [markdown]
# ## Data Ingestion

# %%
import pandas as pd

# %%
goodreads = pd.read_csv('./data/goodreads.csv')

# %%
columns = goodreads.columns.tolist()

# %%
goodreads[columns[:]].head()
# Out:
#    bookID                                              title  \
# 0       1  Harry Potter and the Half-Blood Prince (Harry ...
# 1       2  Harry Potter and the Order of the Phoenix (Har...
# 2       4  Harry Potter and the Chamber of Secrets (Harry...
# 3       5  Harry Potter and the Prisoner of Azkaban (Harr...
# 4       8  Harry Potter Boxed Set  Books 1-5 (Harry Potte...
#
#                       authors  average_rating        isbn         isbn13  \
# 0  J.K. Rowling/Mary GrandPré            4.57  0439785960  9780439785969
# 1  J.K. Rowling/Mary GrandPré            4.49  0439358078  9780439358071
# 2                J.K. Rowling            4.42  0439554896  9780439554893
# 3  J.K. Rowling/Mary GrandPré            4.56  043965548X  9780439655484
# 4  J.K. Rowling/Mary GrandPré            4.78  0439682584  9780439682589
#
#   language_code    num_pages  ratings_count  text_reviews_count  \
# 0           eng          652        2095690               27591
# ...

# %%
goodreads[columns[7:]].head()
# Out:
#      num_pages  ratings_count  text_reviews_count publication_date  \
# 0          652        2095690               27591        9/16/2006
# 1          870        2153167               29221         9/1/2004
# 2          352           6333                 244        11/1/2003
# 3          435        2339585               36325         5/1/2004
# 4         2690          41428                 164        9/13/2004
#
#          publisher
# 0  Scholastic Inc.
# 1  Scholastic Inc.
# 2       Scholastic
# 3  Scholastic Inc.
# 4       Scholastic

# %%
for i,x in enumerate(columns):
    print(f"{i+1}. {x}")
# Out:
# 1. bookID
# 2. title
# 3. authors
# 4. average_rating
# 5. isbn
# 6. isbn13
# 7. language_code
# 8.   num_pages
# 9. ratings_count
# 10. text_reviews_count
# 11. publication_date
# 12. publisher

# %%
goodreads.head(10).to_csv('./data/goodreads_sample.csv')

# %% [markdown]
# ## Good Reads with Genre

# %%
goodread_w_genre = pd.read_csv('./data/goodreads_w_genre.csv')

# %%
goodread_w_genre_col = goodread_w_genre.columns.tolist()

# %%
goodread_w_genre[goodread_w_genre_col[:5]].head()
# Out:
#    Unnamed: 0                                               Book  \
# 0           0                              To Kill a Mockingbird
# 1           1  Harry Potter and the Philosopher’s Stone (Harr...
# 2           2                                Pride and Prejudice
# 3           3                          The Diary of a Young Girl
# 4           4                                        Animal Farm
#
#           Author                                        Description  \
# 0     Harper Lee  The unforgettable novel of a childhood in a sl...
# 1   J.K. Rowling  Harry Potter thinks he is an ordinary boy - un...
# 2    Jane Austen  Since its immediate success in 1813, Pride and...
# 3     Anne Frank  Discovered in the attic in which she spent the...
# 4  George Orwell  Librarian's note: There is an Alternate Cover ...
#
#                                               Genres
# 0  ['Classics', 'Fiction', 'Historical Fiction', ...
# 1  ['Fantasy', 'Fiction', 'Young Adult', 'Magic',...
# ...

# %%
goodread_w_genre[goodread_w_genre_col[5:]].head()
# Out:
#    Avg_Rating Num_Ratings                                                URL
# 0        4.27   5,691,311  https://www.goodreads.com/book/show/2657.To_Ki...
# 1        4.47   9,278,135  https://www.goodreads.com/book/show/72193.Harr...
# 2        4.28   3,944,155  https://www.goodreads.com/book/show/1885.Pride...
# 3        4.18   3,488,438  https://www.goodreads.com/book/show/48855.The_...
# 4        3.98   3,575,172  https://www.goodreads.com/book/show/170448.Ani...

# %%
for i,x in enumerate(goodread_w_genre_col):
    print(f"{i+1}. {x}")
# Out:
# 1. Unnamed: 0
# 2. Book
# 3. Author
# 4. Description
# 5. Genres
# 6. Avg_Rating
# 7. Num_Ratings
# 8. URL

# %%
goodread_w_genre
# Out:
#       Unnamed: 0                                               Book  \
# 0              0                              To Kill a Mockingbird
# 1              1  Harry Potter and the Philosopher’s Stone (Harr...
# 2              2                                Pride and Prejudice
# 3              3                          The Diary of a Young Girl
# 4              4                                        Animal Farm
# ...          ...                                                ...
# 9995        9995                    Breeders (Breeders Trilogy, #1)
# 9996        9996                                             Dynamo
# 9997        9997                              The Republic of Trees
# 9998        9998                     Waking Up (Healing Hearts, #1)
# 9999        9999                 Bits and Pieces: Tales and Sonnets
#
#                  Author                                        Description  \
# ...

# %%
print(f"Books with Nan: {goodread_w_genre[goodread_w_genre.Book.isna()].shape[0]}")
# Out:
# Books with Nan: 0

# %%
print(goodread_w_genre.drop_duplicates(['Book', 'Author', 'Description']).shape[0])
print(goodread_w_genre.drop_duplicates(['Book', 'Author']).shape[0])
print(goodread_w_genre.shape[0])
# Out:
# 9971
# 9896
# 10000
